# %%
import pyximport
pyximport.install()

import mem

# %%
dir(mem)
# Out:
# ['Foo',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__reduce_cython__',
#  '__setstate_cython__',
#  '__spec__',
#  '__test__']

# %%
import pyximport
pyximport.install(setup_args={
            'language': 'c++',
            "include_dirs": ".",
            'extra_compile_args': ["-Wno-cpp","-L/Users/lishuo121/workspace/learn_slice/cython","-lc_lib", "-Wno-unused-function", "-O2", "-march=native", '-stdlib=libc++', '-std=c++11'],
            'extra_link_args': ["-O2","-L/Users/lishuo121/workspace/learn_slice/cython","-lc_lib", "-march=native", '-stdlib=libc++'],
        
    })

import uvloop
uvloop.
# Out:
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# cdef __tcp_init_uv_handle(UVStream handle, Loop loop, unsigned int flags):
#                           ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:1:26: 'UVStream' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# cdef __tcp_init_uv_handle(UVStream handle, Loop loop, unsigned int flags):
#                                            ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:1:43: 'Loop' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         raise convert_error(err)
#
#     handle._finish_init()
#
#
# cdef __tcp_bind(UVStream handle, system.sockaddr* addr, unsigned int flags):
#                 ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:19:16: 'UVStream' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         raise convert_error(err)
#
#     handle._finish_init()
#
#
# cdef __tcp_bind(UVStream handle, system.sockaddr* addr, unsigned int flags):
#                                  ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:19:33: 'system' is not declared
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     if err < 0:
#         exc = convert_error(err)
#         raise exc
#
#
# cdef __tcp_open(UVStream handle, int sockfd):
#                 ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:28:16: 'UVStream' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     if err < 0:
#         exc = convert_error(err)
#         raise exc
#
#
# cdef __tcp_get_socket(UVSocketHandle handle):
#                       ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:37:22: 'UVSocketHandle' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         raise convert_error(err)
#
#     return PseudoSocket(buf.ss_family, uv.SOCK_STREAM, 0, fileno)
#
#
# @cython.no_gc_clear
# ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:55:0: Cdef functions/classes cannot take arbitrary decorators.
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
#     return PseudoSocket(buf.ss_family, uv.SOCK_STREAM, 0, fileno)
#
#
# @cython.no_gc_clear
# cdef class TCPServer(UVStreamServer):
#                      ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:56:21: First base of 'TCPServer' is not an extension type
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# @cython.no_gc_clear
# cdef class TCPServer(UVStreamServer):
#
#     @staticmethod
#     cdef TCPServer new(Loop loop, object protocol_factory, Server server,
#                        ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:59:23: 'Loop' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# @cython.no_gc_clear
# cdef class TCPServer(UVStreamServer):
#
#     @staticmethod
#     cdef TCPServer new(Loop loop, object protocol_factory, Server server,
#                                                            ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:59:59: 'Server' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         except Exception as exc:
#             self._fatal_error(exc, True)
#         else:
#             self._mark_as_open()
#
#     cdef bind(self, system.sockaddr* addr, unsigned int flags=0):
#                     ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:85:20: 'system' is not declared
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         except Exception as exc:
#             self._fatal_error(exc, True)
#         else:
#             self._mark_as_open()
#
#     cdef UVStream _make_new_transport(self, object protocol, object waiter,
#          ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:94:9: 'UVStream' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         tr = TCPTransport.new(self._loop, protocol, self._server, waiter,
#                               context)
#         return <UVStream>tr
#
#
# @cython.no_gc_clear
# ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:102:0: Cdef functions/classes cannot take arbitrary decorators.
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#                               context)
#         return <UVStream>tr
#
#
# @cython.no_gc_clear
# cdef class TCPTransport(UVStream):
#                         ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:103:24: First base of 'TCPTransport' is not an extension type
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# @cython.no_gc_clear
# cdef class TCPTransport(UVStream):
#
#     @staticmethod
#     cdef TCPTransport new(Loop loop, object protocol, Server server,
#                           ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:106:26: 'Loop' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# @cython.no_gc_clear
# cdef class TCPTransport(UVStream):
#
#     @staticmethod
#     cdef TCPTransport new(Loop loop, object protocol, Server server,
#                                                       ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:106:54: 'Server' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         return super().get_extra_info(name, default)
#
#     cdef _new_socket(self):
#         return __tcp_get_socket(<UVSocketHandle>self)
#
#     cdef bind(self, system.sockaddr* addr, unsigned int flags=0):
#                     ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:171:20: 'system' is not declared
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
#     cdef _open(self, int sockfd):
#         self._ensure_alive()
#         __tcp_open(<UVStream>self, sockfd)
#
#     cdef connect(self, system.sockaddr* addr):
#                        ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:179:23: 'system' is not declared
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         cdef _TCPConnectRequest req
#         req = _TCPConnectRequest(self._loop, self)
#         req.connect(addr)
#
#
# cdef class _TCPConnectRequest(UVRequest):
#                               ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:185:30: First base of '_TCPConnectRequest' is not an extension type
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
#
# cdef class _TCPConnectRequest(UVRequest):
#     cdef:
#         TCPTransport transport
#         uv.uv_connect_t _req_data
#         ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:188:8: 'uv' is not declared
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     def __cinit__(self, loop, transport):
#         self.request = <uv.uv_req_t*>&self._req_data
#         self.request.data = <void*>self
#         self.transport = transport
#
#     cdef connect(self, system.sockaddr* addr):
#                        ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:195:23: 'system' is not declared
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#             self.on_done()
#             raise exc
#
#
# cdef void __tcp_connect_callback(
#     uv.uv_connect_t* req,
#     ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:208:4: 'uv' is not declared
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# cdef __tcp_get_socket(UVSocketHandle handle):
#     cdef:
#         int buf_len = sizeof(system.sockaddr_storage)
#         int fileno
#         int err
#         system.sockaddr_storage buf
#         ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:42:8: 'system' is not declared
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# cdef __tcp_init_uv_handle(UVStream handle, Loop loop, unsigned int flags):
#     cdef int err
#
#     handle._handle = <uv.uv_handle_t*>PyMem_RawMalloc(sizeof(uv.uv_tcp_t))
#                       ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:4:22: 'uv' is not declared
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# cdef __tcp_init_uv_handle(UVStream handle, Loop loop, unsigned int flags):
#     cdef int err
#
#     handle._handle = <uv.uv_handle_t*>PyMem_RawMalloc(sizeof(uv.uv_tcp_t))
#                                       ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:4:38: undeclared name not builtin: PyMem_RawMalloc
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# cdef __tcp_init_uv_handle(UVStream handle, Loop loop, unsigned int flags):
#     cdef int err
#
#     handle._handle = <uv.uv_handle_t*>PyMem_RawMalloc(sizeof(uv.uv_tcp_t))
#                                                              ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:4:61: undeclared name not builtin: uv
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# cdef __tcp_init_uv_handle(UVStream handle, Loop loop, unsigned int flags):
#     cdef int err
#
#     handle._handle = <uv.uv_handle_t*>PyMem_RawMalloc(sizeof(uv.uv_tcp_t))
#                      ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:4:21: Casting temporary Python object to non-numeric non-Python type
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# cdef __tcp_init_uv_handle(UVStream handle, Loop loop, unsigned int flags):
#     cdef int err
#
#     handle._handle = <uv.uv_handle_t*>PyMem_RawMalloc(sizeof(uv.uv_tcp_t))
#     if handle._handle is NULL:
#                       ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:5:22: Invalid types for 'is' (Python object, void *)
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     if handle._handle is NULL:
#         handle._abort_init()
#         raise MemoryError()
#
#     err = uv.uv_tcp_init_ex(handle._loop.uvloop,
#                             <uv.uv_tcp_t*>handle._handle,
#                              ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:10:29: 'uv' is not a cimported module
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     err = uv.uv_tcp_init_ex(handle._loop.uvloop,
#                             <uv.uv_tcp_t*>handle._handle,
#                             flags)
#     if err < 0:
#         handle._abort_init()
#         raise convert_error(err)
#               ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:14:14: undeclared name not builtin: convert_error
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     handle._finish_init()
#
#
# cdef __tcp_bind(UVStream handle, system.sockaddr* addr, unsigned int flags):
#     cdef int err
#     err = uv.uv_tcp_bind(<uv.uv_tcp_t *>handle._handle,
#                           ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:21:26: 'uv' is not a cimported module
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         raise exc
#
#
# cdef __tcp_open(UVStream handle, int sockfd):
#     cdef int err
#     err = uv.uv_tcp_open(<uv.uv_tcp_t *>handle._handle,
#                           ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:30:26: 'uv' is not a cimported module
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
#
# cdef __tcp_open(UVStream handle, int sockfd):
#     cdef int err
#     err = uv.uv_tcp_open(<uv.uv_tcp_t *>handle._handle,
#                          <uv.uv_os_sock_t>sockfd)
#                           ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:31:26: 'uv' is not a cimported module
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         raise exc
#
#
# cdef __tcp_get_socket(UVSocketHandle handle):
#     cdef:
#         int buf_len = sizeof(system.sockaddr_storage)
#                              ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:39:29: undeclared name not builtin: system
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         int err
#         system.sockaddr_storage buf
#
#     fileno = handle._fileno()
#
#     err = uv.uv_tcp_getsockname(<uv.uv_tcp_t*>handle._handle,
#                                  ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:46:33: 'uv' is not a cimported module
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         system.sockaddr_storage buf
#
#     fileno = handle._fileno()
#
#     err = uv.uv_tcp_getsockname(<uv.uv_tcp_t*>handle._handle,
#                                 <system.sockaddr*>&buf,
#                                  ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:47:33: 'system' is not a cimported module
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
#     fileno = handle._fileno()
#
#     err = uv.uv_tcp_getsockname(<uv.uv_tcp_t*>handle._handle,
#                                 <system.sockaddr*>&buf,
#                                 &buf_len)
#                                 ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:48:32: Cannot convert 'int *' to Python object
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#                                 <system.sockaddr*>&buf,
#                                 &buf_len)
#     if err < 0:
#         raise convert_error(err)
#
#     return PseudoSocket(buf.ss_family, uv.SOCK_STREAM, 0, fileno)
#            ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:52:11: undeclared name not builtin: PseudoSocket
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
#         cdef TCPServer handle
#         handle = TCPServer.__new__(TCPServer)
#         handle._init(loop, protocol_factory, server, backlog,
#                      ssl, ssl_handshake_timeout, ssl_shutdown_timeout)
#         __tcp_init_uv_handle(<UVStream>handle, loop, flags)
#                               ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:70:30: 'UVStream' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#                      ssl, ssl_handshake_timeout, ssl_shutdown_timeout)
#         __tcp_init_uv_handle(<UVStream>handle, loop, flags)
#         return handle
#
#     cdef _new_socket(self):
#         return __tcp_get_socket(<UVSocketHandle>self)
#                                  ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:74:33: 'UVSocketHandle' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         return __tcp_get_socket(<UVSocketHandle>self)
#
#     cdef _open(self, int sockfd):
#         self._ensure_alive()
#         try:
#             __tcp_open(<UVStream>self, sockfd)
#                         ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:79:24: 'UVStream' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#             self._mark_as_open()
#
#     cdef bind(self, system.sockaddr* addr, unsigned int flags=0):
#         self._ensure_alive()
#         try:
#             __tcp_bind(<UVStream>self, addr, flags)
#                         ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:88:24: 'UVStream' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     cdef UVStream _make_new_transport(self, object protocol, object waiter,
#                                       object context):
#         cdef TCPTransport tr
#         tr = TCPTransport.new(self._loop, protocol, self._server, waiter,
#                               context)
#         return <UVStream>tr
#                 ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:99:16: 'UVStream' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#                           object waiter, object context):
#
#         cdef TCPTransport handle
#         handle = TCPTransport.__new__(TCPTransport)
#         handle._init(loop, protocol, server, waiter, context)
#         __tcp_init_uv_handle(<UVStream>handle, loop, uv.AF_UNSPEC)
#                               ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:112:30: 'UVStream' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         return handle
#
#     cdef _set_nodelay(self):
#         cdef int err
#         self._ensure_alive()
#         err = uv.uv_tcp_nodelay(<uv.uv_tcp_t*>self._handle, 1)
#                                  ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:121:33: 'uv' is not a cimported module
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         cdef:
#             int err
#             int buf_len
#
#         buf_len = sizeof(system.sockaddr_storage)
#         err = uv.uv_tcp_getsockname(<uv.uv_tcp_t*>self._handle,
#                                      ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:136:37: 'uv' is not a cimported module
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#             int err
#             int buf_len
#
#         buf_len = sizeof(system.sockaddr_storage)
#         err = uv.uv_tcp_getsockname(<uv.uv_tcp_t*>self._handle,
#                                     <system.sockaddr*>&self.__sockname,
#                                      ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:137:37: 'system' is not a cimported module
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#             int err
#             int buf_len
#
#         buf_len = sizeof(system.sockaddr_storage)
#         err = uv.uv_tcp_getsockname(<uv.uv_tcp_t*>self._handle,
#                                     <system.sockaddr*>&self.__sockname,
#                                                       ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:137:54: Cannot take address of Python object attribute '_TCPTransport__sockname'
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#             int buf_len
#
#         buf_len = sizeof(system.sockaddr_storage)
#         err = uv.uv_tcp_getsockname(<uv.uv_tcp_t*>self._handle,
#                                     <system.sockaddr*>&self.__sockname,
#                                     &buf_len)
#                                     ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:138:36: Cannot convert 'int *' to Python object
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#             # will crash later (in roughly the same way how
#             # an asyncio transport would.)
#             self.__sockname_set = 1
#
#         buf_len = sizeof(system.sockaddr_storage)
#         err = uv.uv_tcp_getpeername(<uv.uv_tcp_t*>self._handle,
#                                      ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:147:37: 'uv' is not a cimported module
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#             # an asyncio transport would.)
#             self.__sockname_set = 1
#
#         buf_len = sizeof(system.sockaddr_storage)
#         err = uv.uv_tcp_getpeername(<uv.uv_tcp_t*>self._handle,
#                                     <system.sockaddr*>&self.__peername,
#                                      ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:148:37: 'system' is not a cimported module
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#             # an asyncio transport would.)
#             self.__sockname_set = 1
#
#         buf_len = sizeof(system.sockaddr_storage)
#         err = uv.uv_tcp_getpeername(<uv.uv_tcp_t*>self._handle,
#                                     <system.sockaddr*>&self.__peername,
#                                                       ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:148:54: Cannot take address of Python object attribute '_TCPTransport__peername'
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#             self.__sockname_set = 1
#
#         buf_len = sizeof(system.sockaddr_storage)
#         err = uv.uv_tcp_getpeername(<uv.uv_tcp_t*>self._handle,
#                                     <system.sockaddr*>&self.__peername,
#                                     &buf_len)
#                                     ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:149:36: Cannot convert 'int *' to Python object
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         if err >= 0:
#             # Same as few lines above -- we don't really care
#             # about error case here.
#             self.__peername_set = 1
#
#         UVBaseTransport._call_connection_made(self)
#         ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:155:8: undeclared name not builtin: UVBaseTransport
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         UVBaseTransport._call_connection_made(self)
#
#     def get_extra_info(self, name, default=None):
#         if name == 'sockname':
#             if self.__sockname_set:
#                 return __convert_sockaddr_to_pyaddr(
#                        ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:160:23: undeclared name not builtin: _TCPTransport__convert_sockaddr_to_pyaddr
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
#     def get_extra_info(self, name, default=None):
#         if name == 'sockname':
#             if self.__sockname_set:
#                 return __convert_sockaddr_to_pyaddr(
#                     <system.sockaddr*>&self.__sockname)
#                      ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:161:21: 'system' is not a cimported module
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
#     def get_extra_info(self, name, default=None):
#         if name == 'sockname':
#             if self.__sockname_set:
#                 return __convert_sockaddr_to_pyaddr(
#                     <system.sockaddr*>&self.__sockname)
#                                       ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:161:38: Cannot take address of Python object attribute '_TCPTransport__sockname'
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#                 return __convert_sockaddr_to_pyaddr(
#                     <system.sockaddr*>&self.__sockname)
#         elif name == 'peername':
#             if self.__peername_set:
#                 return __convert_sockaddr_to_pyaddr(
#                     <system.sockaddr*>&self.__peername)
#                      ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:165:21: 'system' is not a cimported module
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#                 return __convert_sockaddr_to_pyaddr(
#                     <system.sockaddr*>&self.__sockname)
#         elif name == 'peername':
#             if self.__peername_set:
#                 return __convert_sockaddr_to_pyaddr(
#                     <system.sockaddr*>&self.__peername)
#                                       ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:165:38: Cannot take address of Python object attribute '_TCPTransport__peername'
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#                 return __convert_sockaddr_to_pyaddr(
#                     <system.sockaddr*>&self.__peername)
#         return super().get_extra_info(name, default)
#
#     cdef _new_socket(self):
#         return __tcp_get_socket(<UVSocketHandle>self)
#                                  ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:169:33: 'UVSocketHandle' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     cdef _new_socket(self):
#         return __tcp_get_socket(<UVSocketHandle>self)
#
#     cdef bind(self, system.sockaddr* addr, unsigned int flags=0):
#         self._ensure_alive()
#         __tcp_bind(<UVStream>self, addr, flags)
#                     ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:173:20: 'UVStream' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         self._ensure_alive()
#         __tcp_bind(<UVStream>self, addr, flags)
#
#     cdef _open(self, int sockfd):
#         self._ensure_alive()
#         __tcp_open(<UVStream>self, sockfd)
#                     ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:177:20: 'UVStream' is not a type identifier
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     cdef:
#         TCPTransport transport
#         uv.uv_connect_t _req_data
#
#     def __cinit__(self, loop, transport):
#         self.request = <uv.uv_req_t*>&self._req_data
#                         ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:191:24: 'uv' is not a cimported module
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         TCPTransport transport
#         uv.uv_connect_t _req_data
#
#     def __cinit__(self, loop, transport):
#         self.request = <uv.uv_req_t*>&self._req_data
#         self.request.data = <void*>self
#                             ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:192:28: Cannot convert 'void *' to Python object
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         self.request.data = <void*>self
#         self.transport = transport
#
#     cdef connect(self, system.sockaddr* addr):
#         cdef int err
#         err = uv.uv_tcp_connect(<uv.uv_connect_t*>self.request,
#                                  ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:197:33: 'uv' is not a cimported module
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#         self.transport = transport
#
#     cdef connect(self, system.sockaddr* addr):
#         cdef int err
#         err = uv.uv_tcp_connect(<uv.uv_connect_t*>self.request,
#                                 <uv.uv_tcp_t*>self.transport._handle,
#                                  ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:198:33: 'uv' is not a cimported module
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     cdef connect(self, system.sockaddr* addr):
#         cdef int err
#         err = uv.uv_tcp_connect(<uv.uv_connect_t*>self.request,
#                                 <uv.uv_tcp_t*>self.transport._handle,
#                                 addr,
#                                 __tcp_connect_callback)
#                                 ^
# ------------------------------------------------------------
#
# /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx:200:32: Cannot convert 'void (<error>, int) noexcept nogil' to Python object
# ---------------------------------------------------------------------------
# CompileError                              Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/pyximport/_pyximport3.py:314, in PyxImportLoader.create_module(self, spec)
#     313 try:
# --> 314     so_path = build_module(spec.name, pyxfilename=spec.origin, pyxbuild_dir=self._pyxbuild_dir,
#     315                            inplace=self._inplace, language_level=self._language_level)
#     316     self.path = so_path
#
# File /opt/homebrew/lib/python3.11/site-packages/pyximport/_pyximport3.py:197, in build_module(name, pyxfilename, pyxbuild_dir, inplace, language_level)
#     196 try:
# --> 197     so_path = pyxbuild.pyx_to_dll(pyxfilename, extension_mod,
#     198                                   build_in_temp=build_in_temp,
#     199                                   pyxbuild_dir=pyxbuild_dir,
#     200                                   setup_args=sargs,
#     201                                   inplace=inplace,
#     202                                   reload_support=pyxargs.reload_support)
#     203 finally:
#
# File /opt/homebrew/lib/python3.11/site-packages/pyximport/pyxbuild.py:103, in pyx_to_dll(filename, ext, force_rebuild, build_in_temp, pyxbuild_dir, setup_args, reload_support, inplace)
#     102 obj_build_ext = dist.get_command_obj("build_ext")
# --> 103 dist.run_commands()
#     104 so_path = obj_build_ext.get_outputs()[0]
#
# File /opt/homebrew/lib/python3.11/site-packages/setuptools/_distutils/dist.py:969, in Distribution.run_commands(self)
#     968 for cmd in self.commands:
# --> 969     self.run_command(cmd)
#
# File /opt/homebrew/lib/python3.11/site-packages/setuptools/dist.py:989, in Distribution.run_command(self, command)
#     986 # Postpone defaults until all explicit configuration is considered
#     987 # (setup() args, config files, command line and plugins)
# --> 989 super().run_command(command)
#
# File /opt/homebrew/lib/python3.11/site-packages/setuptools/_distutils/dist.py:988, in Distribution.run_command(self, command)
#     987 cmd_obj.ensure_finalized()
# --> 988 cmd_obj.run()
#     989 self.have_run[command] = 1
#
# File /opt/homebrew/lib/python3.11/site-packages/setuptools/_distutils/command/build_ext.py:345, in build_ext.run(self)
#     344 # Now actually compile and link everything.
# --> 345 self.build_extensions()
#
# File /opt/homebrew/lib/python3.11/site-packages/setuptools/_distutils/command/build_ext.py:467, in build_ext.build_extensions(self)
#     466 else:
# --> 467     self._build_extensions_serial()
#
# File /opt/homebrew/lib/python3.11/site-packages/setuptools/_distutils/command/build_ext.py:493, in build_ext._build_extensions_serial(self)
#     492 with self._filter_build_errors(ext):
# --> 493     self.build_extension(ext)
#
# File /opt/homebrew/lib/python3.11/site-packages/Cython/Distutils/build_ext.py:130, in build_ext.build_extension(self, ext)
#     118 options = {
#     119     'use_listing_file': self.get_extension_attr(ext, 'cython_create_listing'),
#     120     'emit_linenums': self.get_extension_attr(ext, 'cython_line_directives'),
#    (...)
#     127     'compile_time_env': self.get_extension_attr(ext, 'cython_compile_time_env', default=None),
#     128 }
# --> 130 new_ext = cythonize(
#     131     ext,force=self.force, quiet=self.verbose == 0, **options
#     132 )[0]
#     134 ext.sources = new_ext.sources
#
# File /opt/homebrew/lib/python3.11/site-packages/Cython/Build/Dependencies.py:1154, in cythonize(module_list, exclude, nthreads, aliases, quiet, force, language, exclude_failures, show_all_warnings, **options)
#    1153     for args in to_compile:
# -> 1154         cythonize_one(*args)
#    1156 if exclude_failures:
#
# File /opt/homebrew/lib/python3.11/site-packages/Cython/Build/Dependencies.py:1321, in cythonize_one(pyx_file, c_file, fingerprint, quiet, options, raise_on_failure, embedded_metadata, full_module_name, show_all_warnings, progress)
#    1320 if raise_on_failure:
# -> 1321     raise CompileError(None, pyx_file)
#    1322 elif os.path.exists(c_file):
#
# CompileError: /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 10
#       1 import pyximport
#       2 pyximport.install(setup_args={
#       3             'language': 'c++',
#       4             "include_dirs": ".",
#    (...)
#       7
#       8     })
# ---> 10 from uvloop.handles.tcp import TCPServer
#
# File /opt/homebrew/lib/python3.11/site-packages/pyximport/_pyximport3.py:332, in PyxImportLoader.create_module(self, spec)
#     329 import traceback
#     330 exc = ImportError("Building module %s failed: %s" % (
#     331     spec.name, traceback.format_exception_only(*sys.exc_info()[:2])))
# --> 332 raise exc.with_traceback(tb)
#
# File /opt/homebrew/lib/python3.11/site-packages/pyximport/_pyximport3.py:314, in PyxImportLoader.create_module(self, spec)
#     312 def create_module(self, spec):
#     313     try:
# --> 314         so_path = build_module(spec.name, pyxfilename=spec.origin, pyxbuild_dir=self._pyxbuild_dir,
#     315                                inplace=self._inplace, language_level=self._language_level)
#     316         self.path = so_path
#     317         spec.origin = so_path
#
# File /opt/homebrew/lib/python3.11/site-packages/pyximport/_pyximport3.py:197, in build_module(name, pyxfilename, pyxbuild_dir, inplace, language_level)
#     195     os.chdir(common)
#     196 try:
# --> 197     so_path = pyxbuild.pyx_to_dll(pyxfilename, extension_mod,
#     198                                   build_in_temp=build_in_temp,
#     199                                   pyxbuild_dir=pyxbuild_dir,
#     200                                   setup_args=sargs,
#     201                                   inplace=inplace,
#     202                                   reload_support=pyxargs.reload_support)
#     203 finally:
#     204     os.chdir(olddir)
#
# File /opt/homebrew/lib/python3.11/site-packages/pyximport/pyxbuild.py:103, in pyx_to_dll(filename, ext, force_rebuild, build_in_temp, pyxbuild_dir, setup_args, reload_support, inplace)
#     101 try:
#     102     obj_build_ext = dist.get_command_obj("build_ext")
# --> 103     dist.run_commands()
#     104     so_path = obj_build_ext.get_outputs()[0]
#     105     if obj_build_ext.inplace:
#     106         # Python distutils get_outputs()[ returns a wrong so_path
#     107         # when --inplace ; see https://bugs.python.org/issue5977
#     108         # workaround:
#
# File /opt/homebrew/lib/python3.11/site-packages/setuptools/_distutils/dist.py:969, in Distribution.run_commands(self)
#     964 """Run each command that was seen on the setup script command line.
#     965 Uses the list of commands found and cache of command objects
#     966 created by 'get_command_obj()'.
#     967 """
#     968 for cmd in self.commands:
# --> 969     self.run_command(cmd)
#
# File /opt/homebrew/lib/python3.11/site-packages/setuptools/dist.py:989, in Distribution.run_command(self, command)
#     985 self.set_defaults()
#     986 # Postpone defaults until all explicit configuration is considered
#     987 # (setup() args, config files, command line and plugins)
# --> 989 super().run_command(command)
#
# File /opt/homebrew/lib/python3.11/site-packages/setuptools/_distutils/dist.py:988, in Distribution.run_command(self, command)
#     986 cmd_obj = self.get_command_obj(command)
#     987 cmd_obj.ensure_finalized()
# --> 988 cmd_obj.run()
#     989 self.have_run[command] = 1
#
# File /opt/homebrew/lib/python3.11/site-packages/setuptools/_distutils/command/build_ext.py:345, in build_ext.run(self)
#     342     self.compiler.set_link_objects(self.link_objects)
#     344 # Now actually compile and link everything.
# --> 345 self.build_extensions()
#
# File /opt/homebrew/lib/python3.11/site-packages/setuptools/_distutils/command/build_ext.py:467, in build_ext.build_extensions(self)
#     465     self._build_extensions_parallel()
#     466 else:
# --> 467     self._build_extensions_serial()
#
# File /opt/homebrew/lib/python3.11/site-packages/setuptools/_distutils/command/build_ext.py:493, in build_ext._build_extensions_serial(self)
#     491 for ext in self.extensions:
#     492     with self._filter_build_errors(ext):
# --> 493         self.build_extension(ext)
#
# File /opt/homebrew/lib/python3.11/site-packages/Cython/Distutils/build_ext.py:130, in build_ext.build_extension(self, ext)
#     116     ext.language = 'c++'
#     118 options = {
#     119     'use_listing_file': self.get_extension_attr(ext, 'cython_create_listing'),
#     120     'emit_linenums': self.get_extension_attr(ext, 'cython_line_directives'),
#    (...)
#     127     'compile_time_env': self.get_extension_attr(ext, 'cython_compile_time_env', default=None),
#     128 }
# --> 130 new_ext = cythonize(
#     131     ext,force=self.force, quiet=self.verbose == 0, **options
#     132 )[0]
#     134 ext.sources = new_ext.sources
#     135 super(build_ext, self).build_extension(ext)
#
# File /opt/homebrew/lib/python3.11/site-packages/Cython/Build/Dependencies.py:1154, in cythonize(module_list, exclude, nthreads, aliases, quiet, force, language, exclude_failures, show_all_warnings, **options)
#    1152 else:
#    1153     for args in to_compile:
# -> 1154         cythonize_one(*args)
#    1156 if exclude_failures:
#    1157     failed_modules = set()
#
# File /opt/homebrew/lib/python3.11/site-packages/Cython/Build/Dependencies.py:1321, in cythonize_one(pyx_file, c_file, fingerprint, quiet, options, raise_on_failure, embedded_metadata, full_module_name, show_all_warnings, progress)
#    1319 if any_failures:
#    1320     if raise_on_failure:
# -> 1321         raise CompileError(None, pyx_file)
#    1322     elif os.path.exists(c_file):
#    1323         os.remove(c_file)
#
# ImportError: Building module uvloop.handles.tcp failed: ['Cython.Compiler.Errors.CompileError: /opt/homebrew/lib/python3.11/site-packages/uvloop/handles/tcp.pyx\n']
