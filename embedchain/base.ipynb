# %%
from embedchain import App

# app = Pipeline()
app = App.from_config(config_path="./config.yaml")

# %%
from embedchain.loaders.github import GithubLoader
loader = GithubLoader(
    config={
        "token":"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"
        }
    )

# %%
app.add("repo:embedchain/embedchain type:repo", data_type="github", loader=loader)
# Out:
# Searching data from github:   0%|          | 0/1 [00:00<?, ?it/s]WARNI [root] Failed to read file: docs/favicon.png
# WARNI [root] Failed to read file: docs/images/checks-passed.png
# WARNI [root] Failed to read file: docs/images/cover.gif
# WARNI [root] Failed to read file: docs/images/fly_io.png
# WARNI [root] Failed to read file: docs/images/fullstack-api-server.png
# WARNI [root] Failed to read file: docs/images/fullstack-chunks.png
# WARNI [root] Failed to read file: docs/images/fullstack.png
# WARNI [root] Failed to read file: docs/images/gradio_app.png
# WARNI [root] Failed to read file: docs/images/langsmith.png
# WARNI [root] Failed to read file: docs/images/og.png
# WARNI [root] Failed to read file: docs/images/slack-ai.png
# WARNI [root] Failed to read file: docs/images/whatsapp.jpg
# WARNI [root] Failed to read file: examples/full_stack/backend/requirements.txt
# WARNI [root] Failed to read file: examples/full_stack/frontend/public/favicon.ico
# ...

# %%
response = app.query("What is Embedchain?")

# %%
response = app.query("如何实现github repo query的?")
# Out:
# To implement a GitHub repository query in the `GithubLoader` class, you can follow these steps:
#
# 1. Extract the necessary information from the query string. This includes the repository name and any search terms. You can use regular expressions to extract these elements. For example:
# ```python
# query_terms = shlex.split(query)
# repo_name = None
# search_terms = []
# for term in query_terms:
#     if "repo:" in term:
#         repo_name = term.split(":")[1]
#     elif "type:" in term:
#         search_terms.append(term)
# ```
# 2. Check if the query is valid by checking if it provides a repository name and any search terms. If the query is not valid, raise a `ValueError` with a message indicating what is missing. For example:
# ```python
# if len(query_terms) < 1 or "repo:" not in query:
#     raise ValueError("GithubLoader requires a search query with `repo:` term. Refer docs - `https:/docs.embedchain.ai/data-sources/github`")
# ```
# ...

# %%
response = app.query("如何实现github  query的?")

# %%
app.add("repo:secretflow/scql type:repo", data_type="github", loader=loader)
# Out:
# Searching data from github:   0%|          | 0/1 [00:00<?, ?it/s]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# WARNI [root] Failed to read file: docs/_static/favicon.ico
# WARNI [root] Failed to read file: docs/_static/logo-dark.png
# WARNI [root] Failed to read file: docs/_static/logo-light.png
# WARNI [root] Failed to read file: docs/imgs/deployment.png
# ...

# %%
response = app.query("what is scql")
